# %% [markdown]
# <a href="https://colab.research.google.com/github/ashbun23/IOD/blob/Lab-9/IOD_Lab_9_1_Regression_NN_with_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 9.1: NN with Keras
# INSTRUCTIONS:
# - Read the guides and hints, then create the necessary analysis and code to find an answer and conclusion for the task below.
# - **NOTE**: This is a Regression problem. Consider the appropriate:
#     - Activation function
#     - Loss/Cost Function
#     - Metrics

# %% [markdown]
# ### Import libraries

# %%
# insert code here
# insert code here
## Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
# import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import plot_model
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ### Load data
# Load the Diabetes dataset from **SciKit-Learn**.

# %%
# insert code here
from sklearn.datasets import load_diabetes

# %% [markdown]
# ### Prepare input data

# %%
# insert code here

# Regression Example With Boston Dataset: Standardized and Larger
from pandas import read_csv
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from scikeras.wrappers import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
# load dataset
dataframe = read_csv("housing.csv", delim_whitespace=True, header=None)
dataset = dataframe.values
# split into input (X) and output (Y) variables
X = dataset[:,0:13]
Y = dataset[:,13]
# define the model
def larger_model():
	# create model
	model = Sequential()
	model.add(Dense(13, input_shape=(13,), kernel_initializer='normal', activation='relu'))
	model.add(Dense(6, kernel_initializer='normal', activation='relu'))
	model.add(Dense(1, kernel_initializer='normal'))
	# Compile model
	model.compile(loss='mean_squared_error', optimizer='adam')
	return model
# evaluate model with standardized dataset
estimators = []
estimators.append(('standardize', StandardScaler()))
estimators.append(('mlp', KerasRegressor(model=larger_model, epochs=50, batch_size=5, verbose=0)))
pipeline = Pipeline(estimators)
kfold = KFold(n_splits=10)
results = cross_val_score(pipeline, X, Y, cv=kfold, scoring='neg_mean_squared_error')
print("Larger: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-bead0490ad08> in <cell line: 2>()
#       1 # insert code here
# ----> 2 load_diabetes.head()
#
# AttributeError: 'function' object has no attribute 'head'

# %% [markdown]
# ### Split the data (training/test)

# %%
# insert code here

# %% [markdown]
# ### Create the model's architecture

# %%
# insert code here

# %% [markdown]
# ### Compile the model

# %%
# insert code here

# %% [markdown]
# ### Fit the training data

# %%
# %%time
# insert code here

# %% [markdown]
# ### Create predictions

# %%
# insert code here

# %% [markdown]
# ### Evaluate the model

# %%
# insert code here

# %% [markdown]
# ### Visualisation of cost

# %%
# insert code here

# %% [markdown]
# ### Visualisation of residuals

# %%
# insert code here

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2024 Institute of Data
#
#
# ---
#
#
#
# ---
